# %% [markdown]
# <h1><center>Data science for Geographers</center></h1>
#
# <h2><center>Practical 2 - Data modelling in R using multiple regression</center></h2>

# %% [markdown]
# ![image2.png](attachment:image2.png)

# %% [markdown]
# # Practical 2: Data analysis using R

# %% [markdown]
# ## Contents<a class="anchor" id="contents"></a>
#
# - 1. [Introduction](#section1)
#     - [Reminder: What are we trying to do?](#section1.1)
# - 2. [Summarising and visualising](#section2)
#     - [Summary statistics and tables](#section2.1)
#     - [Plots (boxplots and histograms)](#section2.2)
#     - [An aside about plotting](#section2.3)
#     - [Saving plots for presentations or publication](#section2.4)
#     - [Creating 'Table 1'](#section2.5)
# - 3. [Linear Regression in R](#section3)
#     - [Simple Linear Regression](#section3.1)
#     - [Multiple Linear Regression](#section3.2)
# - 4. [Independent analysis exercises](#section4)
#     - [Good Coding Practice](#section4.1)

# %% [markdown]
# ## 1. Introduction<a class="anchor" id="section1"></a>

# %% [markdown]
# ### Reminder: What are we trying to do?<a class="anchor" id="section1.1"></a>
#
# If you remember from the previous practical, we are going through all of the steps for a research project using secondary quantitative data. In our particular example, we are undertaking a research project where we are interested in the geography of the availabillity of tobbaco products (i.e. similar to the paper below):
#
# https://tobaccocontrol.bmj.com/content/tobaccocontrol/25/1/75.full.pdf
#
# Last week, we went through the process of cleaning, recoding and merging the datasets together so that by the end we had a dataset ready to answer our research questions. This final dataset consists of an area-level dataset (as opposed to individual level data for example). Our unit of analysis is datazones and for each datazone we have information on the level of deprivation (in terms of employment levels, health, education and income), the numbers of tobacco retailers per unit of population, smoking rates among pregnant women and whether the area is urban or rural. Since there are approximately 6500 datazones in Scotland we now have a dataset which looks like this, with approximately 6500 rows of data:
#
# ![image.png](attachment:image.png)
#
# So, we have got the boring part out of the way! Now it's on to the interesting part, the actual analysis of this data! Let's first etablish the three research questions we are going to try and answer today. What we are going to do today is showcase how we might approach answering questions like these:
#
# 1. Is the number of tobacco retailers in urban areas associated with smoking rates in datazones in Scotland?
# 2. Is this association independent of the level of deprivation in these datazones?
# 3. Is the level of deprivation in urban datazones associated with the number of tobacco retailers?
#
# First thing we have to do, as always, is load in the packages we need. As last week everything we need is in the tidyverse collection of packages. So, let's import that now...

# %%
#First let's load in the packages we need - we will need skimr and viridis later in the practical
library(tidyverse)
library(knitr) #for descriptive tables

install.packages("skimr") #for nice summary plots
library(skimr)

install.packages("viridis") #for colourblind-friendly palette
library(viridis)

install.packages("table1")
library(table1) #for nice 'Table 1' for papers
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
# Error in value[[3L]](cond): Package ‘modelr’ version 0.1.8 cannot be unloaded:
#  Error in unloadNamespace(package) : namespace ‘modelr’ is imported by ‘tidyverse’ so cannot be unloaded
#
# Traceback:
#
# 1. library(modelr)
# 2. tryCatch(unloadNamespace(package), error = function(e) {
#  .     P <- if (!is.null(cc <- conditionCall(e)))
#  .         paste("Error in", deparse(cc)[1L], ": ")
#  .     else "Error : "
#  .     stop(gettextf("Package %s version %s cannot be unloaded:\n %s",
#  .         sQuote(package), oldversion, paste0(P, conditionMessage(e),
#  .             "\n")), domain = NA)
#  . })
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. value[[3L]](cond)
# 6. stop(gettextf("Package %s version %s cannot be unloaded:\n %s",
#  .     sQuote(package), oldversion, paste0(P, conditionMessage(e),
#  .         "\n")), domain = NA)

# %% [markdown]
# And now let's read the data we created in last weeks practical...

# %%
analysis_data <- read_csv("merged_data.csv")
# Out:
# Rows: 6973 Columns: 21
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# chr  (5): datazone, UR6_2013_2014, income_quintile, access_quintile, urban_r...
# dbl (16): retailer_count, total_population, simd_decile, simd_rank, simd_qui...
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %% [markdown]
# And take a look at the data to remind ourselves what is there...

# %%
head(analysis_data)
# Out:
#   datazone  retailer_count total_population simd_decile simd_rank simd_quintile
# 1 S01006506 34             894              7           4691      4
# 2 S01006507 19             793              7           4862      4
# 3 S01006508 16             624              9           5686      5
# 4 S01006509 12             537              7           4332      4
# 5 S01006510 20             663              6           3913      3
# 6 S01006511 17             759              9           6253      5
#   income_rank health_rank employment_rank education_rank ⋯ crime_rank
# 1 3936        5174        3220            5887           ⋯ 4664.0
# 2 4829        5051        4481            4384           ⋯ 4602.0
# 3 4460        5942        5110            5915           ⋯ 4563.5
# 4 3481        3871        3229            6401           ⋯ 5626.0
# 5 3344        3049        3448            4092           ⋯ 3885.0
# 6 5469        5783        5346            5410           ⋯ 6928.0
#   housing_rank alcohol_admissions drug_admissions smoking_rate
# 1 3248.0        29                 30              9.09
# 2 3486.0       130                126             11.11
# 3 5342.0        71                 18              4.76
# 4 4394.5        80                 28             17.65
# 5 3736.0        89                 44             12.50
# 6 5924.0        55                  0              0.00
#   UR6_2013_2014          retailers_adj income_quintile access_quintile
# 1 Accessible Small Towns 38.03132      Third           Fourth
# 2 Accessible Small Towns 23.95965      Fourth          Second
# 3 Accessible Small Towns 25.64103      Fourth          Fourth
# 4 Accessible Small Towns 22.34637      Third           Third
# 5 Accessible Small Towns 30.16591      Third           Least deprived
# 6 Accessible Small Towns 22.39789      Fourth          Fourth
#   urban_rural_2cat
# 1 Urban
# 2 Urban
# 3 Urban
# 4 Urban
# 5 Urban
# 6 Urban

# %% [markdown]
# ### Exercise
#
# To refresh our memories from last week, lets do one more variable recode to see what you can remember:
#
# 1. Create new variables called `health_quintile` and `retailers_adj_quintile`. These should be based on the existing `health_rank` and `retailers_adj` variables but dividing them into five equal groups.
#
# 2. Change these two new variables so that they are factor variables. Label the `health_quintile` the same as the other "quintile" variables i.e. "Most deprived", "Second, "Third", "Fourth" and "Least deprived". Label the `retailer_adj` as you see fit.
#
# 3. Change the variables `simd_quintile` and `simd_decile` into factors and relabel appropriately (you'll need to think of labels for the `simd_decile` variable.
#
# Bonus points if you can figure out how to do tasks 1 and 2 in one command using the `%>%` command!
#
# <b>Hint: you can use `mutate` and the `ntile` command here as well as `fct_recode` . Refer back to last weeks notebook if you get stuck!

# %%
#1
analysis_data <- analysis_data %>%
    mutate(health_quintile = ntile(health_rank, 5))

analysis_data <- analysis_data %>%
    mutate(retailers_adj_quintile = ntile(retailers_adj, 5))

#2 
analysis_data <- analysis_data %>%
    mutate(retailers_adj_quintile = as.factor(retailers_adj_quintile) %>%
    fct_recode("Lowest availabillity" = "1", 
               "Second" = "2", 
               "Third" = "3", 
               "Fourth " = "4", 
               "Highest availabillity" = "5"))

analysis_data <- analysis_data %>%
    mutate(health_quintile = as.factor(health_quintile) %>%
    fct_recode("Most deprived" = "1", 
               "Second" = "2", 
               "Third" = "3", 
               "Fourth " = "4", 
               "Least deprived" = "5"))

#bonus solution!
analysis_data <- analysis_data %>%
    mutate(health_quintile = ntile(health_rank, 5)) %>%
    mutate(health_quintile = as.factor(health_quintile) %>%
      fct_recode("Most deprived" = "1", 
                 "Second" = "2", 
                 "Third" = "3", 
                 "Fourth " = "4", 
                 "Least deprived" = "5")) %>%
    mutate(retailers_adj_quintile = ntile(retailers_adj, 5)) %>%
    mutate(retailers_adj_quintile = as.factor(retailers_adj_quintile) %>%
      fct_recode("Lowest availabillity" = "1", 
                 "Second" = "2", 
                 "Third" = "3", 
                 "Fourth " = "4", 
                 "Highest availabillity" = "5"))

#3
analysis_data <- analysis_data %>%
    mutate(simd_quintile = as.factor(simd_quintile) %>%
      fct_recode("Most deprived" = "1", 
                 "Second" = "2", 
                 "Third" = "3", 
                 "Fourth " = "4", 
                 "Least deprived" = "5")) %>%
    mutate(simd_decile = as.factor(simd_decile) %>%
      fct_recode("Most deprived" = "1",
                 "Second" = "2", 
                 "Third" = "3", 
                 "Fourth " = "4",
                 "Fifth" = "5",
                 "Sixth" = "6",
                 "Seventh" = "7",
                 "Eighth" = "8",
                 "Ninth" = "9",
                 "Least deprived" = "10"))

# %% [markdown]
# ## 2. Summarising and visualising<a class="anchor" id="section2"></a>

# %%
#Solutions

#1
analysis_data <- analysis_data %>%
    mutate(health_quintile = ntile(health_rank, 5))
           
#2
analysis_data <- analysis_data %>%
    mutate(health_quintile = as.factor(health_quintile) %>%
      fct_recode("Most deprived" = "1", 
                 "Second" = "2", 
                 "Third" = "3", 
                 "Fourth " = "4", 
                 "Least deprived" = "5"))

# %% [markdown]
# ### Summary statistics and tables<a class="anchor" id="section2.1"></a>
#
# Before we get stuck into the modelling for our research questions, let's draw up some plots and descriptives of our data. You should have some familliarity with these commands from "Key Methods".
#
#
# First let's look at some of our categorical variables using `count`.

# %%
#Rename 'UR6_2013_2014' as urban_rural so you know what it is

analysis_data <- analysis_data %>% 
    rename(urban_rural = UR6_2013_2014)

# %%
#Tables for the categorical variables
analysis_data %>% 
  count(urban_rural)

analysis_data %>% 
  count(simd_quintile)

analysis_data %>% 
  count(simd_decile)

analysis_data %>% 
  count(simd_quintile)
# Out:
#   urban_rural            n
# 1 Accessible Rural        802
# 2 Accessible Small Towns  663
# 3 Large Urban            2316
# 4 Other Urban            2518
# 5 Remote Rural            425
# 6 Remote Small Towns      249
#   simd_quintile  n
# 1 Most deprived  1395
# 2 Second         1395
# 3 Third          1394
# 4 Fourth         1394
# 5 Least deprived 1395
#    simd_decile    n
# 1  Most deprived  697
# 2  Second         698
# 3  Third          697
# 4  Fourth         698
# 5  Fifth          698
# 6  Sixth          696
# 7  Seventh        698
# 8  Eighth         696
# 9  Ninth          697
# 10 Least deprived 698
#   simd_quintile  n
# 1 Most deprived  1395
# 2 Second         1395
# 3 Third          1394
# 4 Fourth         1394
# 5 Least deprived 1395

# %% [markdown]
# Now let's look at some of the continuous variables using `summary()`...
#
# Remember when looking at the below code that using the `$` is a method for selecting a particular variable from a dataset...

# %%
#Summaries for all of the variables
summary(analysis_data$simd_rank)
summary(analysis_data$total_population)
# Out:
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#       1    1744    3487    3488    5232    6976
#    Min. 1st Qu.  Median    Mean 3rd Qu.    Max.
#     258     635     755     778     886    3847

# %% [markdown]
# Note that you can also look at all variables together by just using the `summary()` command with just the data object. Like...

# %%
summary(analysis_data)
# Out:
#    datazone         retailer_count   total_population         simd_decile
#  Length:6973        Min.   :  1.00   Min.   : 258     Second        : 698
#  Class :character   1st Qu.: 14.00   1st Qu.: 635     Fourth        : 698
#  Mode  :character   Median : 19.00   Median : 755     Fifth         : 698
#                     Mean   : 22.02   Mean   : 778     Seventh       : 698
#                     3rd Qu.: 27.00   3rd Qu.: 886     Least deprived: 698
#                     Max.   :246.00   Max.   :3847     Most deprived : 697
#                                                       (Other)       :2786
#    simd_rank           simd_quintile   income_rank    health_rank
#  Min.   :   1   Most deprived :1395   Min.   :   1   Min.   :   1
#  1st Qu.:1744   Second        :1395   1st Qu.:1744   1st Qu.:1744
#  Median :3487   Third         :1394   Median :3487   Median :3488
#  Mean   :3488   Fourth        :1394   Mean   :3487   Mean   :3488
#  3rd Qu.:5232   Least deprived:1395   3rd Qu.:5230   3rd Qu.:5233
#  Max.   :6976                         Max.   :6969   Max.   :6976
#
#  employment_rank education_rank  access_rank     crime_rank    housing_rank
#  Min.   :   1    Min.   :   1   Min.   :   1   Min.   :   1   Min.   :   1
#  1st Qu.:1744    1st Qu.:1745   1st Qu.:1745   1st Qu.:1744   1st Qu.:1747
#  Median :3487    Median :3489   Median :3489   Median :3487   Median :3490
#  Mean   :3487    Mean   :3489   Mean   :3489   Mean   :3487   Mean   :3490
#  3rd Qu.:5230    3rd Qu.:5233   3rd Qu.:5233   3rd Qu.:5230   3rd Qu.:5233
#  Max.   :6974    Max.   :6976   Max.   :6976   Max.   :6928   Max.   :6974
#
#  alcohol_admissions drug_admissions    smoking_rate   urban_rural
#  Min.   :   0.0     Min.   :   0.00   Min.   : 0.00   Length:6973
#  1st Qu.:  35.0     1st Qu.:  16.00   1st Qu.: 3.03   Class :character
#  Median :  74.0     Median :  50.00   Median :11.11   Mode  :character
#  Mean   : 102.4     Mean   :  98.11   Mean   :13.57
#  3rd Qu.: 138.0     3rd Qu.: 133.00   3rd Qu.:21.43
#  Max.   :1656.0     Max.   :1826.00   Max.   :75.00
#
#  retailers_adj     income_quintile    access_quintile    urban_rural_2cat
#  Min.   :  2.688   Length:6973        Length:6973        Length:6973
#  1st Qu.: 19.493   Class :character   Class :character   Class :character
#  Median : 25.526   Mode  :character   Mode  :character   Mode  :character
#  Mean   : 28.674
#  3rd Qu.: 33.557
#  Max.   :263.949
#
#        health_quintile           retailers_adj_quintile
#  Most deprived :1395   Lowest availabillity :1395
#  Second        :1395   Second               :1395
#  Third         :1395   Third                :1395
#  Fourth        :1394   Fourth               :1394
#  Least deprived:1394   Highest availabillity:1394

# %% [markdown]
# You might be wondering why R doesnt try and do summaries for all of the variables? Well, because we have told R which of our variables are factors and which are numerical (continuous) R knows which variables to include in the summary command i.e. only the numerical ones.
#
# If you would like a summary of all of the variables in the dataset you can use `skim` from the `skimr` package which we installed earlier.

# %%
analysis_data %>% 
    skimr::skim()
# Out:
# A skim_df: 23 × 20
#
# | <!--/--> | skim_type &lt;chr&gt; | skim_variable &lt;chr&gt; | n_missing &lt;int&gt; | complete_rate &lt;dbl&gt; | character.min &lt;int&gt; | character.max &lt;int&gt; | character.empty &lt;int&gt; | character.n_unique &lt;int&gt; | character.whitespace &lt;int&gt; | factor.ordered &lt;lgl&gt; | factor.n_unique &lt;int&gt; | factor.top_counts &lt;chr&gt; | numeric.mean &lt;dbl&gt; | numeric.sd &lt;dbl&gt; | numeric.p0 &lt;dbl&gt; | numeric.p25 &lt;dbl&gt; | numeric.p50 &lt;dbl&gt; | numeric.p75 &lt;dbl&gt; | numeric.p100 &lt;dbl&gt; | numeric.hist &lt;chr&gt; |
# |---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|---|
# | 1 | character | datazone               | 0 | 1 |  9 |  9 |  0 | 6973 |  0 |    NA | NA | NA                                         |         NA |         NA |         NA |         NA |         NA |         NA |        NA | NA    |
# | 2 | character | urban_rural            | 0 | 1 | 11 | 22 |  0 |    6 |  0 |    NA | NA | NA                                         |         NA |         NA |         NA |         NA |         NA |         NA |        NA | NA    |
# | 3 | character | income_quintile        | 0 | 1 |  5 | 14 |  0 |    5 |  0 |    NA | NA | NA                                         |         NA |         NA |         NA |         NA |         NA |         NA |        NA | NA    |
# | 4 | character | access_quintile        | 0 | 1 |  5 | 14 |  0 |    5 |  0 |    NA | NA | NA                                         |         NA |         NA |         NA |         NA |         NA |         NA |        NA | NA    |
# | 5 | character | urban_rural_2cat       | 0 | 1 |  5 |  5 |  0 |    2 |  0 |    NA | NA | NA                                         |         NA |         NA |         NA |         NA |         NA |         NA |        NA | NA    |
# | 6 | factor    | simd_decile            | 0 | 1 | NA | NA | NA |   NA | NA | FALSE | 10 | Sec: 698, Fou: 698, Fif: 698, Sev: 698     |         NA |         NA |         NA |         NA |         NA |         NA |        NA | NA    |
# | 7 | factor    | simd_quintile          | 0 | 1 | NA | NA | NA |   NA | NA | FALSE |  5 | Mos: 1395, Sec: 1395, Lea: 1395, Thi: 1394 |         NA |         NA |         NA |         NA |         NA |         NA |        NA | NA    |
# | 8 | factor    | health_quintile        | 0 | 1 | NA | NA | NA |   NA | NA | FALSE |  5 | Mos: 1395, Sec: 1395, Thi: 1395, Fou: 1394 |         NA |         NA |         NA |         NA |         NA |         NA |        NA | NA    |
# | 9 | factor    | retailers_adj_quintile | 0 | 1 | NA | NA | NA |   NA | NA | FALSE |  5 | Low: 1395, Sec: 1395, Thi: 1395, Fou: 1394 |         NA |         NA |         NA |         NA |         NA |         NA |        NA | NA    |
# | 10 | numeric   | retailer_count         | 0 | 1 | NA | NA | NA |   NA | NA |    NA | NA | NA                                         |   22.01793 |   12.47167 |   1.000000 |   14.00000 |   19.00000 |   27.00000 |  246.0000 | ▇▁▁▁▁ |
# | 11 | numeric   | total_population       | 0 | 1 | NA | NA | NA |   NA | NA |    NA | NA | NA                                         |  777.97218 |  218.56134 | 258.000000 |  635.00000 |  755.00000 |  886.00000 | 3847.0000 | ▇▁▁▁▁ |
# | 12 | numeric   | simd_rank              | 0 | 1 | NA | NA | NA |   NA | NA |    NA | NA | NA                                         | 3487.80381 | 2014.03217 |   1.000000 | 1744.00000 | 3487.00000 | 5232.00000 | 6976.0000 | ▇▇▇▇▇ |
# | 13 | numeric   | income_rank            | 0 | 1 | NA | NA | NA |   NA | NA |    NA | NA | NA                                         | 3487.00000 | 2013.07603 |   1.000000 | 1744.00000 | 3487.00000 | 5230.00000 | 6969.0000 | ▇▇▇▇▇ |
# | 14 | numeric   | health_rank            | 0 | 1 | NA | NA | NA |   NA | NA |    NA | NA | NA                                         | 3488.16263 | 2014.27099 |   1.000000 | 1744.00000 | 3488.00000 | 5233.00000 | 6976.0000 | ▇▇▇▇▇ |
# | 15 | numeric   | employment_rank        | 0 | 1 | NA | NA | NA |   NA | NA |    NA | NA | NA                                         | 3487.00043 | 2013.07677 |   1.000000 | 1744.00000 | 3487.00000 | 5230.00000 | 6974.0000 | ▇▇▇▇▇ |
# | 16 | numeric   | education_rank         | 0 | 1 | NA | NA | NA |   NA | NA |    NA | NA | NA                                         | 3489.12577 | 2014.01528 |   1.000000 | 1745.00000 | 3489.00000 | 5233.00000 | 6976.0000 | ▇▇▇▇▇ |
# | 17 | numeric   | access_rank            | 0 | 1 | NA | NA | NA |   NA | NA |    NA | NA | NA                                         | 3488.80066 | 2014.13902 |   1.000000 | 1745.00000 | 3489.00000 | 5233.00000 | 6976.0000 | ▇▇▇▇▇ |
# | 18 | numeric   | crime_rank             | 0 | 1 | NA | NA | NA |   NA | NA |    NA | NA | NA                                         | 3487.02725 | 2013.12007 |   1.000000 | 1744.00000 | 3487.00000 | 5230.00000 | 6928.0000 | ▇▇▇▇▇ |
# | 19 | numeric   | housing_rank           | 0 | 1 | NA | NA | NA |   NA | NA |    NA | NA | NA                                         | 3489.98709 | 2013.09829 |   1.000000 | 1747.00000 | 3490.00000 | 5233.00000 | 6974.0000 | ▇▇▇▇▇ |
# | 20 | numeric   | alcohol_admissions     | 0 | 1 | NA | NA | NA |   NA | NA |    NA | NA | NA                                         |  102.43841 |   98.05629 |   0.000000 |   35.00000 |   74.00000 |  138.00000 | 1656.0000 | ▇▁▁▁▁ |
# | 21 | numeric   | drug_admissions        | 0 | 1 | NA | NA | NA |   NA | NA |    NA | NA | NA                                         |   98.11473 |  134.79560 |   0.000000 |   16.00000 |   50.00000 |  133.00000 | 1826.0000 | ▇▁▁▁▁ |
# | 22 | numeric   | smoking_rate           | 0 | 1 | NA | NA | NA |   NA | NA |    NA | NA | NA                                         |   13.56683 |   12.46121 |   0.000000 |    3.03000 |   11.11000 |   21.43000 |   75.0000 | ▇▃▁▁▁ |
# | 23 | numeric   | retailers_adj          | 0 | 1 | NA | NA | NA |   NA | NA |    NA | NA | NA                                         |   28.67448 |   15.03733 |   2.688172 |   19.49318 |   25.52553 |   33.55705 |  263.9485 | ▇▁▁▁▁ |
# ── Data Summary ────────────────────────
#                            Values
# Name                       Piped data
# Number of rows             6973
# Number of columns          23
# _______________________
# Column type frequency:
#   character                5
#   factor                   4
#   numeric                  14
# ________________________
# Group variables            None
#
# ── Variable type: character ────────────────────────────────────────────────────
#   skim_variable    n_missing complete_rate min max empty n_unique whitespace
# 1 datazone                 0             1   9   9     0     6973          0
# 2 urban_rural              0             1  11  22     0        6          0
# 3 income_quintile          0             1   5  14     0        5          0
# 4 access_quintile          0             1   5  14     0        5          0
# 5 urban_rural_2cat         0             1   5   5     0        2          0
#
# ── Variable type: factor ───────────────────────────────────────────────────────
#   skim_variable          n_missing complete_rate ordered n_unique
# 1 simd_decile                    0             1 FALSE         10
# 2 simd_quintile                  0             1 FALSE          5
# 3 health_quintile                0             1 FALSE          5
# 4 retailers_adj_quintile         0             1 FALSE          5
#   top_counts
# 1 Sec: 698, Fou: 698, Fif: 698, Sev: 698
# 2 Mos: 1395, Sec: 1395, Lea: 1395, Thi: 1394
# 3 Mos: 1395, Sec: 1395, Thi: 1395, Fou: 1394
# 4 Low: 1395, Sec: 1395, Thi: 1395, Fou: 1394
#
# ── Variable type: numeric ──────────────────────────────────────────────────────
#    skim_variable      n_missing complete_rate   mean     sd     p0     p25
#  1 retailer_count             0             1   22.0   12.5   1      14
#  2 total_population           0             1  778.   219.  258     635
#  3 simd_rank                  0             1 3488.  2014.    1    1744
#  4 income_rank                0             1 3487   2013.    1    1744
#  5 health_rank                0             1 3488.  2014.    1    1744
#  6 employment_rank            0             1 3487.  2013.    1    1744
#  7 education_rank             0             1 3489.  2014.    1    1745
#  8 access_rank                0             1 3489.  2014.    1    1745
#  9 crime_rank                 0             1 3487.  2013.    1    1744
# 10 housing_rank               0             1 3490.  2013.    1    1747
# 11 alcohol_admissions         0             1  102.    98.1   0      35
# 12 drug_admissions            0             1   98.1  135.    0      16
# 13 smoking_rate               0             1   13.6   12.5   0       3.03
# 14 retailers_adj              0             1   28.7   15.0   2.69   19.5
#       p50    p75  p100 hist
#  1   19     27    246  ▇▁▁▁▁
#  2  755    886   3847  ▇▁▁▁▁
#  3 3487   5232   6976  ▇▇▇▇▇
#  4 3487   5230   6969  ▇▇▇▇▇
#  5 3488   5233   6976  ▇▇▇▇▇
#  6 3487   5230   6974  ▇▇▇▇▇
#  7 3489   5233   6976  ▇▇▇▇▇
#  8 3489   5233   6976  ▇▇▇▇▇
#  9 3487   5230   6928  ▇▇▇▇▇
# 10 3490   5233   6974  ▇▇▇▇▇
# 11   74    138   1656  ▇▁▁▁▁
# 12   50    133   1826  ▇▁▁▁▁
# 13   11.1   21.4   75  ▇▃▁▁▁
# 14   25.5   33.6  264. ▇▁▁▁▁

# %% [markdown]
# ### Plots (boxplots and histograms)<a class="anchor" id="section2.2"></a>
#
# It is also good practice to look at our data using graphs and plots, particularly boxplots and histograms.
#
# Let's look at the `retailers_adj` variable.

# %%
#Histogram and boxplot for the tobacco retailers
ggplot(data = analysis_data) +
    geom_histogram(mapping = aes(x = retailers_adj), binwidth = 0.5) +
    theme_bw()

#We can also add in a second variable to see the distribution of retailers over that variable, e.g.
ggplot(data = analysis_data) +
    geom_histogram(mapping = aes(x = retailers_adj, fill = simd_quintile), binwidth = 0.5) +
    scale_fill_viridis(discrete = TRUE) +
    theme_bw()

#Or we can divide this into separate plots
ggplot(data = analysis_data) +
    geom_histogram(mapping = aes(x = retailers_adj, color = simd_quintile), binwidth = 0.5) +
    facet_wrap(~simd_quintile) +
    scale_color_viridis(discrete = TRUE) +
    theme_bw()

ggplot(data = analysis_data, mapping = aes(retailers_adj)) +
  geom_boxplot()

#Some other plots we might want to look at:

#ggplot(data = my_data) +
#  geom_histogram(mapping = aes(x = smoking_rate), binwidth = 0.1) +
#  theme_bw()
# Out:
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# Looking at these graphs it seems we need to trim some outlying obervations (removing observations with retailers greater than 100)

# %%
analysis_data <- analysis_data %>%
    filter(retailers_adj <= 100)

# %% [markdown]
# In many cases, boxplots are more useful when combined with categorical variables...

# %%
ggplot(data = analysis_data, mapping = aes(x = simd_quintile, y = smoking_rate)) +
    geom_boxplot() +
    theme_bw()

ggplot(data = analysis_data, mapping = aes(x = retailers_adj, y = smoking_rate)) +
    geom_boxplot() +
    theme_bw()

ggplot(data = analysis_data, mapping = aes(x = simd_quintile, y = retailers_adj)) +
    geom_boxplot() +
    theme_bw()
# Out:
# Warning message:
# “Continuous x aesthetic -- did you forget aes(group=...)?”
# plot without title
# plot without title
# plot without title

# %% [markdown]
# ### An aside about plotting<a class="anchor" id="section2.3"></a>
#
# There are many options for customising your plots using `ggplot`. Above we have changed the theme using `theme_bw` and created multiple plots using `facet_wrap`. For more options check out https://raw.githubusercontent.com/rstudio/cheatsheets/main/data-visualization.pdf
#
# We have also used the package `viridis` to set the colours used in our plots. Viridis is colourblind-friendly and retains clarity when printed in greyscale - it also looks nice! There are a lot of places online where you can check for colourblind accessibility. Within R you can do this using the `colorBlindness` package (https://cran.r-project.org/web/packages/colorBlindness/vignettes/colorBlindness.html).
#
# Below we will format a plot as if it is for a presentation or publication.

# %% [markdown]
# ### Saving plots for presentations or publication<a class="anchor" id="section2.4"></a>
#
# In your project, you will likely want to include a plot of some description. You can save your plot using `ggsave`.

# %%
#Saving the plot - by default, ggsave saves the last plot you have viewed, however, we want to be more explicit:
#First, give your plot a sensible object name
simd_smoking_boxplot <- 
    ggplot(data = analysis_data, mapping = aes(x = simd_quintile, y = smoking_rate, fill = urban_rural_2cat)) +
    geom_boxplot() +
    theme_bw() +
    scale_fill_viridis_d(begin = 0.2, end = 0.8) #begin and end control the start and end of the viridis colour scale

#Add axis labels - edit the labels to make sense for your simd_smoking_boxplot
my_plot_withlabs <- 
    simd_smoking_boxplot +
    labs(title = "My plot title",
        subtitle = "A subtitle",
        x = "x-axis label",
        y = "y-axis label",
        fill = "Urban/Rural")

#Move the legend to the bottom of the plot
my_plot_withlabs <- 
    my_plot_withlabs + theme(legend.position = "bottom")

ggsave(plot = my_plot_withlabs, 
       file = "simd_smoking_boxplot.png", 
       width = 10, height = 8, dpi = 600)

#Many journals require a certain quality of image for inclusion in published papers
#You can edit this using the dpi option.

# %% [markdown]
# ### Creating 'Table 1'<a class="anchor" id="section2.5"></a>
#
# Whilst we are talking about presentations and publications, it is worth mentioning 'Table 1'. For a paper, you normally need a descriptive 'Table 1' which shows how the variables included in your model relate to your outcome variable. We can use `kable` from the `knitr` package to quickly convert a dataframe to an html table as follows:

# %%
label(analysis_data$urban_rural_2cat) <- "Urban/Rural"
label(analysis_data$smoking_rate) <- "Smoking Rate"
label(analysis_data$simd_quintile) <- "SIMD Quintile"

IRdisplay::display_html(table1(~ urban_rural_2cat + smoking_rate | simd_quintile, data = analysis_data, overall = "Total"))
#You need to use `display_html` from the `IRdisplay` package to render this table from within Notable
#This is not required from within RStudio.
# Out:
# <table class="Rtable1">
# <thead>
# <tr>
# <th class='rowlabel firstrow lastrow'></th>
# <th class='firstrow lastrow'><span class='stratlabel'>Most deprived<br><span class='stratn'>(N=1391)</span></span></th>
# <th class='firstrow lastrow'><span class='stratlabel'>Second<br><span class='stratn'>(N=1387)</span></span></th>
# <th class='firstrow lastrow'><span class='stratlabel'>Third<br><span class='stratn'>(N=1385)</span></span></th>
# <th class='firstrow lastrow'><span class='stratlabel'>Fourth <br><span class='stratn'>(N=1389)</span></span></th>
# <th class='firstrow lastrow'><span class='stratlabel'>Least deprived<br><span class='stratn'>(N=1395)</span></span></th>
# <th class='firstrow lastrow'><span class='stratlabel'>Total<br><span class='stratn'>(N=6947)</span></span></th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td class='rowlabel firstrow'>Urban/Rural</td>
# <td class='firstrow'></td>
# <td class='firstrow'></td>
# <td class='firstrow'></td>
# <td class='firstrow'></td>
# <td class='firstrow'></td>
# <td class='firstrow'></td>
# </tr>
# <tr>
# <td class='rowlabel'>Rural</td>
# <td>45 (3.2%)</td>
# <td>147 (10.6%)</td>
# <td>443 (32.0%)</td>
# <td>473 (34.1%)</td>
# <td>111 (8.0%)</td>
# <td>1219 (17.5%)</td>
# </tr>
# <tr>
# <td class='rowlabel lastrow'>Urban</td>
# <td class='lastrow'>1346 (96.8%)</td>
# <td class='lastrow'>1240 (89.4%)</td>
# <td class='lastrow'>942 (68.0%)</td>
# <td class='lastrow'>916 (65.9%)</td>
# <td class='lastrow'>1284 (92.0%)</td>
# <td class='lastrow'>5728 (82.5%)</td>
# </tr>
# <tr>
# <td class='rowlabel firstrow'>Smoking Rate</td>
# <td class='firstrow'></td>
# <td class='firstrow'></td>
# <td class='firstrow'></td>
# <td class='firstrow'></td>
# <td class='firstrow'></td>
# <td class='firstrow'></td>
# </tr>
# <tr>
# <td class='rowlabel'>Mean (SD)</td>
# <td>25.9 (11.8)</td>
# <td>18.8 (11.5)</td>
# <td>12.4 (9.75)</td>
# <td>7.58 (7.77)</td>
# <td>3.21 (5.32)</td>
# <td>13.6 (12.5)</td>
# </tr>
# <tr>
# <td class='rowlabel lastrow'>Median [Min, Max]</td>
# <td class='lastrow'>25.0 [0, 66.7]</td>
# <td class='lastrow'>17.7 [0, 75.0]</td>
# <td class='lastrow'>11.1 [0, 50.0]</td>
# <td class='lastrow'>6.25 [0, 50.0]</td>
# <td class='lastrow'>0 [0, 50.0]</td>
# <td class='lastrow'>11.1 [0, 75.0]</td>
# </tr>
# </tbody>
# </table>

# %% [markdown]
# ## 3. Linear Regression in R<a class="anchor" id="section3"></a>

# %% [markdown]
# We have seen a hint of some of the results to our research questions but let's complete our analysis formally using regression.
#
# As a reminder, here are our research questions:
#
# 1. Is the number of tobacco retailers associated with smoking rates in datazones in Scotland?
# 2. Is this association independent of the level of deprivation in these datazones?
# 3. Is the level of deprivation in datazones associated with the number of tobacco retailers?
#
# Since we are only interested in urban areas let's remove all non-urban areas first...

# %%
#Create a new analysis file
urban_only <- analysis_data %>%
    filter(urban_rural_2cat == "Urban")

# %%
head(urban_only)
# Out:
#   datazone  retailer_count total_population simd_decile simd_rank
# 1 S01006506 34             894              Seventh     4691
# 2 S01006507 19             793              Seventh     4862
# 3 S01006508 16             624              Ninth       5686
# 4 S01006509 12             537              Seventh     4332
# 5 S01006510 20             663              Sixth       3913
# 6 S01006511 17             759              Ninth       6253
#   simd_quintile  income_rank health_rank employment_rank education_rank ⋯
# 1 Fourth         3936        5174        3220            5887           ⋯
# 2 Fourth         4829        5051        4481            4384           ⋯
# 3 Least deprived 4460        5942        5110            5915           ⋯
# 4 Fourth         3481        3871        3229            6401           ⋯
# 5 Third          3344        3049        3448            4092           ⋯
# 6 Least deprived 5469        5783        5346            5410           ⋯
#   alcohol_admissions drug_admissions smoking_rate urban_rural
# 1  29                 30              9.09        Accessible Small Towns
# 2 130                126             11.11        Accessible Small Towns
# 3  71                 18              4.76        Accessible Small Towns
# 4  80                 28             17.65        Accessible Small Towns
# 5  89                 44             12.50        Accessible Small Towns
# 6  55                  0              0.00        Accessible Small Towns
#   retailers_adj income_quintile access_quintile urban_rural_2cat
# 1 38.03132      Third           Fourth          Urban
# 2 23.95965      Fourth          Second          Urban
# 3 25.64103      Fourth          Fourth          Urban
# 4 22.34637      Third           Third           Urban
# 5 30.16591      Third           Least deprived  Urban
# 6 22.39789      Fourth          Fourth          Urban
#   health_quintile retailers_adj_quintile
# 1 Fourth          Highest availabillity
# 2 Fourth          Third
# 3 Least deprived  Third
# 4 Third           Second
# 5 Third           Fourth
# 6 Least deprived  Second

# %% [markdown]
# ### Simple Linear Regression<a class="anchor" id="section3.1"></a>

# %% [markdown]
# Ok, now we can tackle question 1 using a linear regression:

# %%
#Run a linear regression model
simple_linear_regression <- lm(smoking_rate ~ retailers_adj, data = urban_only, na.action = na.exclude)

# %% [markdown]
# This has produced the model and saved it in an object called `simple_linear_regression`. We now need to view this output using  `summary`...

# %%
summary(simple_linear_regression)
# Out:
# Call:
# lm(formula = smoking_rate ~ retailers_adj, data = urban_only,
#     na.action = na.exclude)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -16.787 -10.675  -2.396   8.191  59.312
#
# Coefficients:
#               Estimate Std. Error t value Pr(>|t|)
# (Intercept)   13.19126    0.43367  30.418   <2e-16 ***
# retailers_adj  0.03730    0.01556   2.397   0.0166 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 12.75 on 5726 degrees of freedom
# Multiple R-squared:  0.001002,	Adjusted R-squared:  0.0008278
# F-statistic: 5.745 on 1 and 5726 DF,  p-value: 0.01657

# %% [markdown]
# We also want confidence intervals...

# %%
confint(simple_linear_regression)
# Out:
#               2.5 %        97.5 %
# (Intercept)   12.341096896 14.0414244
# retailers_adj  0.006793196  0.0678138

# %% [markdown]
# ### Multiple Linear Regression<a class="anchor" id="section3.2"></a>

# %% [markdown]
# Let's look at research question 2...:
#
# 2. Is this association independent of the level of deprivation in these datazones?

# %%
#Add some variables
multiple_linear_regression <- lm(smoking_rate ~ retailers_adj + simd_rank, data = analysis_data, na.action = na.exclude)
summary(multiple_linear_regression)
confint(multiple_linear_regression)
# Out:
# Call:
# lm(formula = smoking_rate ~ retailers_adj + simd_rank, data = analysis_data,
#     na.action = na.exclude)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -26.435  -5.863  -1.082   5.049  59.853
#
# Coefficients:
#                 Estimate Std. Error t value Pr(>|t|)
# (Intercept)    2.863e+01  3.250e-01  88.087  < 2e-16 ***
# retailers_adj -3.340e-02  8.281e-03  -4.034 5.55e-05 ***
# simd_rank     -4.047e-03  5.603e-05 -72.216  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 9.412 on 6944 degrees of freedom
# Multiple R-squared:  0.4298,	Adjusted R-squared:  0.4296
# F-statistic:  2617 on 2 and 6944 DF,  p-value: < 2.2e-16
#               2.5 %        97.5 %
# (Intercept)   27.995027477 29.269394887
# retailers_adj -0.049636011 -0.017169518
# simd_rank     -0.004156437 -0.003936748

# %% [markdown]
# We can also use categorical predictors if we wish. In other words, using the `simd_quintile` variable.
#
# <b>Bonus Question! Before we run this command, can you think why we might want to use a categorical variable, rather than a continuous one?</b>

# %%
multiple_linear_regression <- lm(smoking_rate ~ retailers_adj_quintile, data = analysis_data, na.action = na.exclude)
summary(multiple_linear_regression)
confint(multiple_linear_regression)
# Out:
# Call:
# lm(formula = smoking_rate ~ retailers_adj_quintile, data = analysis_data,
#     na.action = na.exclude)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -14.346 -10.721  -2.441   7.688  62.688
#
# Coefficients:
#                                             Estimate Std. Error t value
# (Intercept)                                 13.46557    0.33323  40.409
# retailers_adj_quintileSecond                 0.65152    0.47126   1.382
# retailers_adj_quintileThird                  0.88054    0.47126   1.868
# retailers_adj_quintileFourth                 0.08523    0.47135   0.181
# retailers_adj_quintileHighest availabillity -1.15323    0.47358  -2.435
#                                             Pr(>|t|)
# (Intercept)                                   <2e-16 ***
# retailers_adj_quintileSecond                  0.1669
# retailers_adj_quintileThird                   0.0617 .
# retailers_adj_quintileFourth                  0.8565
# retailers_adj_quintileHighest availabillity   0.0149 *
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 12.45 on 6942 degrees of freedom
# Multiple R-squared:  0.003186,	Adjusted R-squared:  0.002612
# F-statistic: 5.547 on 4 and 6942 DF,  p-value: 0.0001867
#                                             2.5 %       97.5 %
# (Intercept)                                 12.81232945 14.1188103
# retailers_adj_quintileSecond                -0.27230178  1.5753412
# retailers_adj_quintileThird                 -0.04328386  1.8043591
# retailers_adj_quintileFourth                -0.83876078  1.0092135
# retailers_adj_quintileHighest availabillity -2.08159934 -0.2248621

# %% [markdown]
# And now lets add the categorical simd variable...

# %%
multiple_linear_regression <- lm(smoking_rate ~ retailers_adj_quintile + simd_quintile, 
                                 data = analysis_data, na.action = na.exclude)
summary(multiple_linear_regression)
confint(multiple_linear_regression)
# Out:
# Call:
# lm(formula = smoking_rate ~ retailers_adj_quintile + simd_quintile,
#     data = analysis_data, na.action = na.exclude)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -25.929  -6.295  -1.864   5.285  56.741
#
# Coefficients:
#                                             Estimate Std. Error t value
# (Intercept)                                  26.2946     0.3414  77.023
# retailers_adj_quintileSecond                 -0.4715     0.3612  -1.305
# retailers_adj_quintileThird                  -0.5606     0.3614  -1.551
# retailers_adj_quintileFourth                 -0.3652     0.3615  -1.010
# retailers_adj_quintileHighest availabillity  -0.9852     0.3677  -2.680
# simd_quintileSecond                          -7.0508     0.3620 -19.479
# simd_quintileThird                          -13.3203     0.3652 -36.470
# simd_quintileFourth                         -18.1944     0.3645 -49.913
# simd_quintileLeast deprived                 -22.6868     0.3613 -62.789
#                                             Pr(>|t|)
# (Intercept)                                  < 2e-16 ***
# retailers_adj_quintileSecond                 0.19178
# retailers_adj_quintileThird                  0.12087
# retailers_adj_quintileFourth                 0.31248
# retailers_adj_quintileHighest availabillity  0.00739 **
# simd_quintileSecond                          < 2e-16 ***
# simd_quintileThird                           < 2e-16 ***
# simd_quintileFourth                          < 2e-16 ***
# simd_quintileLeast deprived                  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 9.523 on 6938 degrees of freedom
# Multiple R-squared:  0.4167,	Adjusted R-squared:  0.4161
# F-statistic: 619.7 on 8 and 6938 DF,  p-value: < 2.2e-16
#                                             2.5 %      97.5 %
# (Intercept)                                  25.625364  26.9637988
# retailers_adj_quintileSecond                 -1.179514   0.2365188
# retailers_adj_quintileThird                  -1.269029   0.1477926
# retailers_adj_quintileFourth                 -1.073906   0.3435340
# retailers_adj_quintileHighest availabillity  -1.705951  -0.2644805
# simd_quintileSecond                          -7.760390  -6.3412394
# simd_quintileThird                          -14.036246 -12.6042755
# simd_quintileFourth                         -18.908941 -17.4798062
# simd_quintileLeast deprived                 -23.395079 -21.9784932

# %% [markdown]
# What is going on here? When we add new variables to a model we are essentially adding more dimensions to the data. This can be illustrated by the images below (ignore the axis labels!). The top image is a straightforward linear regression with one outcome and one predictor. The second is a regression with two predictor variables.
#
# ![image-2.png](attachment:image-2.png) ![image.png](attachment:image.png)
#
# We can also add more than 2 variables (but we can't represent on a graph as you cannot go beyond 3 dimensions!). But the principal is the same. In practical terms what we say is we are "adjusting" or "controlling" for the other variables. In other words, any effects we observe in our model we can say occur "independently" of the other variables. If we had observed a significant effect of tobacco retailers after adjusting for deprivation we would conclude that tobacco retailers are associated with smoking irrespective of the level of deprivation in an area.
#
# Let's look at research question 3:
#
# 3. Is the level of deprivation in datazones associated with the number of tobacco retailers?
#
# To answer let's put all of the different parts of the SIMD into our model (i.e. the income_rank, health_rank, employment_rank, education_rank, access_rank, crime_rank and housing_rank variables)

# %%
#Look at predicting retailers
multiple_linear_regression <- lm(retailers_adj ~ income_rank + 
                                 health_rank + 
                                 employment_rank + 
                                 education_rank + 
                                 access_rank + 
                                 crime_rank + 
                                 housing_rank, 
                                 data = urban_only, na.action = na.exclude)

summary(multiple_linear_regression)
confint(multiple_linear_regression)
# Out:
# Call:
# lm(formula = retailers_adj ~ income_rank + health_rank + employment_rank +
#     education_rank + access_rank + crime_rank + housing_rank,
#     data = urban_only, na.action = na.exclude)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -24.178  -6.388  -1.413   4.618  72.104
#
# Coefficients:
#                   Estimate Std. Error t value Pr(>|t|)
# (Intercept)      2.416e+01  5.103e-01  47.351  < 2e-16 ***
# income_rank      1.820e-03  2.956e-04   6.157 7.91e-10 ***
# health_rank     -7.018e-04  2.206e-04  -3.181  0.00148 **
# employment_rank -2.082e-03  2.708e-04  -7.688 1.74e-14 ***
# education_rank   1.588e-03  1.456e-04  10.907  < 2e-16 ***
# access_rank      8.341e-04  8.237e-05  10.126  < 2e-16 ***
# crime_rank      -2.226e-03  9.291e-05 -23.958  < 2e-16 ***
# housing_rank     1.001e-03  9.734e-05  10.281  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 9.889 on 5720 degrees of freedom
# Multiple R-squared:  0.1664,	Adjusted R-squared:  0.1654
# F-statistic: 163.2 on 7 and 5720 DF,  p-value: < 2.2e-16
#                 2.5 %         97.5 %
# (Intercept)     23.1644895528 25.1654115667
# income_rank      0.0012405459  0.0023995254
# health_rank     -0.0011342575 -0.0002693006
# employment_rank -0.0026127661 -0.0015510622
# education_rank   0.0013028109  0.0018737415
# access_rank      0.0006725908  0.0009955261
# crime_rank      -0.0024080878 -0.0020438050
# housing_rank     0.0008099413  0.0011915965

# %% [markdown]
# ## Independent analysis exercises<a class="anchor" id="section4"></a>
#
# Take a look at some of the remaining variables. What might be some other research questions you might explore? To get you started, look at the two health variables we haven't looked at yet; `alcohol_admissions` and `drug_admissions`. For the remainder of the class, have a think about any easy research questions you might examine looking at either of these as a dependent variable. And then:
#
# 1. Think about how you might need to recode these variables and then have a go at carrying this out
# 2. Produce relevant descriptive statistics that might start to address your research question
# 3. Run an appropriate regression model
# 4. Have a think about what other aditional variables you might need to include, in addition to your independent variable of interest and add these to your model.
# 5. Have a think about how you might interpret the analysis, perhaps write a few words of interpretation in a markdown cell below the results.

# %% [markdown]
# ### Good Coding Practice<a class="anchor" id="section4.1"></a>
#
# Now is a good point to mention good coding practice. Use a Style Guide (e.g. https://style.tidyverse.org/) to format your code. As they say: Good coding style is like correct punctuation: you can manage without it, butitsuremakesthingseasiertoread. Nice code helps you work faster and helps you avoid mistakes when you're updating your code. Be consistent in:
# - Spacing (to make readable)
# - Indenting (to show hierarchies in code)
# - Line length (under 80 characters)
# - Commenting appropriately
#
# Make lots of comments - record all the steps you used when processing the data. When you come back to your code in a couple of weeks or months, you may not remember what you were doing, you need to make sure you have enough comments to remind yourself and pick up where you left off. In Notable, you can do this by inserting a new Markdown cell, but in an RStudio script you will need to comment using the `#` as we have done in the Code cells above.
#
# "Your closest collaborator is you six months ago and they don’t reply to email" - Paul Wilson
